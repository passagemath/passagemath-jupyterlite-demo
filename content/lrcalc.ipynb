# %% [markdown]
# # Example notebook for [lrcalc](https://pypi.org/project/lrcalc/)

# %%
import lrcalc

# %%
lrcalc.mult([2,1], [2])
# Out:
# {(2, 2, 1): 1, (4, 1): 1, (3, 1, 1): 1, (3, 2): 1}

# %%
lrcalc.skew([3,2,1], [2,1])
# Out:
# {(2, 1): 2, (1, 1, 1): 1, (3,): 1}
