# %% [markdown]
# # Example notebook for [passagemath-ecl](https://pypi.org/project/passagemath-ecl/)
#
# ## Sage code running *serverless in the browser* using WebAssembly

# %%
from sage.libs.ecl import ecl_eval

# %%
c = ecl_eval('(cons 1 2)'); c
# Out:
# <ECL: (1 . 2)>

# %%
c.car(), c.cdr()
# Out:
# (<ECL: 1>, <ECL: 2>)

# %%
car = ecl_eval("#'car"); car
# Out:
# <ECL: #<compiled-function CAR 0x5bc65a0>>

# %%
cdr = ecl_eval("#'cdr"); cdr
# Out:
# <ECL: #<compiled-function CDR 0x5bc63c0>>

# %%
car([1, 2, 3, 4]), cdr([1, 2, 3, 4])
# Out:
# (<ECL: 1>, <ECL: (2 3 4)>)

# %%
ecl_eval('*features*')
# Out:
# <ECL: (:WALKER :ECL-BYTECMP :CDR-6 :GRAY-STREAMS-MODULE :CDR-1 :CDR-5 :FORMATTER
#  :CDR-7 :ECL :COMMON :COMMON-LISP :ANSI-CL :FFI :PREFIXED-API :CDR-14
#  :PACKAGE-LOCAL-NICKNAMES :CLOS :ECL-PDE :LONG-FLOAT :UNIX
#  :C-COMPATIBLE-VARIADIC-DISPATCH :EMSCRIPTEN :BOEHM-GC :ECL-WEAK-HASH
#  :IEEE-FLOATING-POINT :FLOATING-POINT-EXCEPTIONS :LONG-LONG :LITTLE-ENDIAN
#  :UINT8-T :UINT16-T :UINT32-T :UINT64-T :COMPLEX-FLOAT :CMU-FORMAT
#  :CLOS-STREAMS :UNICODE :WASM32)>
